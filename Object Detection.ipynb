# %%
pip install matplotlib
# Out:
# Requirement already satisfied: matplotlib in c:\users\dharsan_10\anaconda3\lib\site-packages (3.4.3)Note: you may need to restart the kernel to use updated packages.
# Requirement already satisfied: numpy>=1.16 in c:\users\dharsan_10\anaconda3\lib\site-packages (from matplotlib) (1.20.3)
# Requirement already satisfied: pyparsing>=2.2.1 in c:\users\dharsan_10\anaconda3\lib\site-packages (from matplotlib) (3.0.4)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\dharsan_10\anaconda3\lib\site-packages (from matplotlib) (2.8.2)
# Requirement already satisfied: kiwisolver>=1.0.1 in c:\users\dharsan_10\anaconda3\lib\site-packages (from matplotlib) (1.3.1)
# Requirement already satisfied: cycler>=0.10 in c:\users\dharsan_10\anaconda3\lib\site-packages (from matplotlib) (0.10.0)
# Requirement already satisfied: pillow>=6.2.0 in c:\users\dharsan_10\anaconda3\lib\site-packages (from matplotlib) (8.4.0)
# Requirement already satisfied: six in c:\users\dharsan_10\anaconda3\lib\site-packages (from cycler>=0.10->matplotlib) (1.16.0)

# %%
import cv2
from matplotlib import pyplot as plt
  
  
# Opening image
img = cv2.imread("image.jpg")
  
# OpenCV opens images as BRG 
# but we want it as RGB and 
# we also need a grayscale 
# version
img_gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
img_rgb = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
  
# Creates the environment 
# of the picture and shows it
plt.subplot(1, 1, 1)
plt.imshow(img_rgb)
plt.show()

# %%
stop_data = cv2.CascadeClassifier('stop_data.xml')
found = stop_data.detectMultiScale(img_gray,minSize =(20, 20))
  
# Don't do anything if there's 
# no sign
amount_found = len(found)
  
  
if amount_found != 0:
      
    # There may be more than one
    # sign in the image
    for (x, y, width, height) in found:
          
        # We draw a green rectangle around
        # every recognized sign
        cv2.rectangle(img_rgb, (x, y), 
                      (x + height, y + width), 
                      (0, 255, 0), 5)
